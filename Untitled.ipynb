# %%
pip install azureml-interpret
# Out:
# Collecting azureml-interpret
#   Downloading azureml_interpret-1.29.0-py3-none-any.whl (52 kB)
# Collecting interpret-community==0.17.*
#   Downloading interpret_community-0.17.2-py3-none-any.whl (5.9 MB)
# Collecting azureml-core~=1.29.0
#   Downloading azureml_core-1.29.0-py3-none-any.whl (2.2 MB)
# Requirement already satisfied: pandas in c:\users\vijes\anaconda3\lib\site-packages (from interpret-community==0.17.*->azureml-interpret) (1.0.1)
# Requirement already satisfied: scipy in c:\users\vijes\anaconda3\lib\site-packages (from interpret-community==0.17.*->azureml-interpret) (1.4.1)
# Requirement already satisfied: numpy in c:\users\vijes\anaconda3\lib\site-packages (from interpret-community==0.17.*->azureml-interpret) (1.18.1)
# Requirement already satisfied: scikit-learn in c:\users\vijes\anaconda3\lib\site-packages (from interpret-community==0.17.*->azureml-interpret) (0.22.1)
# Collecting interpret-core[required]<=0.2.4,>=0.1.20
#   Downloading interpret_core-0.2.4-py3-none-any.whl (5.8 MB)
# Collecting shap<=0.34.0,>=0.20.0
#   Downloading shap-0.34.0-cp37-cp37m-win_amd64.whl (298 kB)
# Requirement already satisfied: packaging in c:\users\vijes\anaconda3\lib\site-packages (from interpret-community==0.17.*->azureml-interpret) (20.1)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: urllib3>=1.23 in c:\users\vijes\anaconda3\lib\site-packages (from azureml-core~=1.29.0->azureml-interpret) (1.25.8)
# Requirement already satisfied: pyopenssl<21.0.0 in c:\users\vijes\anaconda3\lib\site-packages (from azureml-core~=1.29.0->azureml-interpret) (19.1.0)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Requirement already satisfied: contextlib2<1.0.0 in c:\users\vijes\anaconda3\lib\site-packages (from azureml-core~=1.29.0->azureml-interpret) (0.6.0.post1)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: pytz in c:\users\vijes\anaconda3\lib\site-packages (from azureml-core~=1.29.0->azureml-interpret) (2019.3)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in c:\users\vijes\anaconda3\lib\site-packages (from azureml-core~=1.29.0->azureml-interpret) (2.22.0)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting ruamel.yaml<1.0.0,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Requirement already satisfied: backports.tempfile in c:\users\vijes\anaconda3\lib\site-packages (from azureml-core~=1.29.0->azureml-interpret) (1.0)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.0.0-py2.py3-none-any.whl (663 kB)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0 in c:\users\vijes\anaconda3\lib\site-packages (from azureml-core~=1.29.0->azureml-interpret) (2.8)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in c:\users\vijes\anaconda3\lib\site-packages (from azureml-core~=1.29.0->azureml-interpret) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\vijes\anaconda3\lib\site-packages (from scikit-learn->interpret-community==0.17.*->azureml-interpret) (0.14.1)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\vijes\anaconda3\lib\site-packages (from shap<=0.34.0,>=0.20.0->interpret-community==0.17.*->azureml-interpret) (4.42.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\vijes\anaconda3\lib\site-packages (from packaging->interpret-community==0.17.*->azureml-interpret) (2.4.6)
# Requirement already satisfied: six in c:\users\vijes\anaconda3\lib\site-packages (from packaging->interpret-community==0.17.*->azureml-interpret) (1.14.0)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vijes\anaconda3\lib\site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.29.0->azureml-interpret) (2019.11.28)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.0.1-py2.py3-none-any.whl (68 kB)
# Requirement already satisfied: pywin32==227; sys_platform == "win32" in c:\users\vijes\anaconda3\lib\site-packages (from docker<5.0.0->azureml-core~=1.29.0->azureml-interpret) (227)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\vijes\anaconda3\lib\site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.29.0->azureml-interpret) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\vijes\anaconda3\lib\site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.29.0->azureml-interpret) (2.8)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\vijes\anaconda3\lib\site-packages (from jsonpickle<3.0.0->azureml-core~=1.29.0->azureml-interpret) (1.5.0)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp37-cp37m-win_amd64.whl (118 kB)
# Requirement already satisfied: backports.weakref in c:\users\vijes\anaconda3\lib\site-packages (from backports.tempfile->azureml-core~=1.29.0->azureml-interpret) (1.0.post1)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.2.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\users\vijes\anaconda3\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core~=1.29.0->azureml-interpret) (1.14.0)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\vijes\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle<3.0.0->azureml-core~=1.29.0->azureml-interpret) (2.2.0)
# Collecting azure-core<2.0.0,>=1.9.0
#   Downloading azure_core-1.14.0-py2.py3-none-any.whl (136 kB)
# Requirement already satisfied: pycparser in c:\users\vijes\anaconda3\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core~=1.29.0->azureml-interpret) (2.19)
# Installing collected packages: interpret-core, shap, interpret-community, isodate, oauthlib, requests-oauthlib, msrest, PyJWT, adal, msrestazure, azure-common, azure-graphrbac, websocket-client, docker, pathspec, azure-mgmt-keyvault, azure-mgmt-authorization, jeepney, SecretStorage, azure-mgmt-resource, pyasn1, ndg-httpsclient, jsonpickle, ruamel.yaml.clib, ruamel.yaml, azure-mgmt-storage, azure-core, azure-mgmt-core, azure-mgmt-containerregistry, jmespath, azureml-core, azureml-interpret
# Successfully installed PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 azure-common-1.1.27 azure-core-1.14.0 azure-graphrbac-0.61.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.0.0 azure-mgmt-core-1.2.2 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.29.0 azureml-interpret-1.29.0 docker-4.4.4 interpret-community-0.17.2 interpret-core-0.2.4 isodate-0.6.0 jeepney-0.6.0 jmespath-0.10.0 jsonpickle-2.0.0 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.1 pyasn1-0.4.8 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 shap-0.34.0 websocket-client-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn import svm
from sklearn.model_selection import train_test_split
breast_cancer_data = load_breast_cancer()
classes = breast_cancer_data.target_names.tolist()

# %%
# load the training dataset
bike_data = pd.read_csv('./daily-bike-share.csv')
bike_data.head()
# Out:
#    instant    dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1        0        6           0
# 1        2  1/2/2011       1   0     1        0        0           0
# 2        3  1/3/2011       1   0     1        0        1           1
# 3        4  1/4/2011       1   0     1        0        2           1
# 4        5  1/5/2011       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  rentals
# 0           2  0.344167  0.363625  0.805833   0.160446      331
# 1           2  0.363478  0.353739  0.696087   0.248539      131
# 2           1  0.196364  0.189405  0.437273   0.248309      120
# 3           1  0.200000  0.212122  0.590435   0.160296      108
# 4           1  0.226957  0.229270  0.436957   0.186900       82

# %%
classes = bike_data.target_names.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d892d6507573> in <module>
# ----> 1 classes = bike_data.target_names.tolist()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'target_names'

# %%
bike_data['day'] = pd.DatetimeIndex(bike_data['dteday']).day
bike_data.head(32)
# Out:
#     instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0         1   1/1/2011       1   0     1        0        6           0
# 1         2   1/2/2011       1   0     1        0        0           0
# 2         3   1/3/2011       1   0     1        0        1           1
# 3         4   1/4/2011       1   0     1        0        2           1
# 4         5   1/5/2011       1   0     1        0        3           1
# 5         6   1/6/2011       1   0     1        0        4           1
# 6         7   1/7/2011       1   0     1        0        5           1
# 7         8   1/8/2011       1   0     1        0        6           0
# 8         9   1/9/2011       1   0     1        0        0           0
# 9        10  1/10/2011       1   0     1        0        1           1
# 10       11  1/11/2011       1   0     1        0        2           1
# 11       12  1/12/2011       1   0     1        0        3           1
# 12       13  1/13/2011       1   0     1        0        4           1
# 13       14  1/14/2011       1   0     1        0        5           1
# 14       15  1/15/2011       1   0     1        0        6           0
# 15       16  1/16/2011       1   0     1        0        0           0
# 16       17  1/17/2011       1   0     1        1        1           0
# 17       18  1/18/2011       1   0     1        0        2           1
# 18       19  1/19/2011       1   0     1        0        3           1
season','mnth', 'holiday','weekday','workingday','weathersit','temp', 'atemp', 'hum', 'windspeed']].values, bike_data['rentals'].values
print('Features:',X[:10], '\nLabels:', y[:10], sep='\n')
# Out:
# Features:
# [[1.        1.        0.        6.        0.        2.        0.344167
#   0.363625  0.805833  0.160446 ]
#  [1.        1.        0.        0.        0.        2.        0.363478
#   0.353739  0.696087  0.248539 ]
#  [1.        1.        0.        1.        1.        1.        0.196364
#   0.189405  0.437273  0.248309 ]
#  [1.        1.        0.        2.        1.        1.        0.2
#   0.212122  0.590435  0.160296 ]
#  [1.        1.        0.        3.        1.        1.        0.226957
#   0.22927   0.436957  0.1869   ]
#  [1.        1.        0.        4.        1.        1.        0.204348
#   0.233209  0.518261  0.0895652]
#  [1.        1.        0.        5.        1.        2.        0.196522
#   0.208839  0.498696  0.168726 ]
#  [1.        1.        0.        6.        0.        2.        0.165
#   0.162254  0.535833  0.266804 ]
#  [1.        1.        0.        0.        0.        1.        0.138333
#   0.116175  0.434167  0.36195  ]
#  [1.        1.        0.        1.        1.        1.        0.150833
#   0.150888  0.482917  0.223267 ]]
#
# Labels:
# [331 131 120 108  82  88 148  68  54  41]

# %%
from sklearn.model_selection import train_test_split

# Split data 70%-30% into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

print ('Training Set: %d rows\nTest Set: %d rows' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Training Set: 511 rows
# Test Set: 220 rows

# %%
# Train the model
from sklearn.linear_model import LinearRegression

# Fit a linear regression model on the training set
model = LinearRegression().fit(X_train, y_train)
print (model)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import numpy as np

predictions = model.predict(X_test)
np.set_printoptions(suppress=True)
print('Predicted labels: ', np.round(predictions)[:10])
print('Actual labels   : ' ,y_test[:10])
# Out:
# Predicted labels:  [1896. 1184. 1007.  -28.  314.  385.  475.  590. 1476.  -22.]
# Actual labels   :  [2418  754  222   47  244  145  240  555 3252   38]

# %%
from interpret.ext.blackbox import TabularExplainer

# "features" and "classes" fields are optional
explainer = TabularExplainer(model, 
                             X_train)
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# The option feature_dependence has been renamed to feature_perturbation!
# The option feature_perturbation="independent" is has been renamed to feature_perturbation="interventional"!

# %%
# you can use the training data or the test data here, but test data would allow you to use Explanation Exploration
global_explanation = explainer.explain_global(X_test)

# if you used the PFIExplainer in the previous step, use the next line of code instead
# global_explanation = explainer.explain_global(x_train, true_labels=y_train)

# sorted feature importance values and feature names
sorted_global_importance_values = global_explanation.get_ranked_global_values()
sorted_global_importance_names = global_explanation.get_ranked_global_names()
dict(zip(sorted_global_importance_names, sorted_global_importance_values))

# alternatively, you can print out a dictionary that holds the top K feature names and values
global_explanation.get_feature_importance_dict()
# Out:
# {4: 367.1490553204078,
#  6: 306.29318307810814,
#  9: 73.47464540872345,
#  0: 71.77462706755223,
#  8: 65.5984727483538,
#  1: 43.33164328860745,
#  5: 23.790008827643124,
#  3: 20.50579390686295,
#  2: 16.611114764495387,
#  7: 4.382676028935383}
